# %% [markdown]
# ## Problem defininig
#
# To predict the total sales by using features like money spent on marketing on individual items

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading of dataset

# %%
dat1 = pd.read_csv('Advertising.csv')
dat1
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# ## Domain analysis

# %% [markdown]
# * The independent variables variables are (unnamed : 0 , TV , Radio , Newspaper) & Target value is sales
#
# * The data tells about the money spent on marketing through different mediums & sales values are given

# %% [markdown]
# ## Basics checks

# %%
# No.of rows & cols.
dat1.shape
# Out:
# (200, 5)

# %%
# First 5 rows

dat1.head(5)
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
# Last 5 rows

dat1.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
# Datatypes & col. names can be seen

dat1.dtypes
# Out:
# Unnamed: 0      int64
# TV            float64
# Radio         float64
# Newspaper     float64
# Sales         float64
# dtype: object

# %%
# info. dataset

dat1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %% [markdown]
# ## Insights :
# * No 'Null values' present in this dataset.
# * Except col 1 every features are in float 64 dtype

# %%
# Statistical summary :

dat1.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# ## Insights : (task) -> compare the cols. and write
# *
# * TV col.shows the max.avg of money spent compared to other mediums .
# * Since the std of Radio is least, it shows data is not deviated much among other features

# %% [markdown]
# ## EDA

# %% [markdown]
# ### UNIVARIATE ANALYSIS  -Hist , distplot

# %%
# Numerical col.'TV'

plt.figure(figsize=(5,5))
sns.histplot(data = dat1, x = "TV",kde = True)
# Out:
# <Axes: xlabel='TV', ylabel='Count'>

# %%
# Numerical col.'Radio'

plt.figure(figsize=(5,5))
sns.histplot(data = dat1, x = "Radio",kde = True)
# Out:
# <Axes: xlabel='Radio', ylabel='Count'>

# %%
# Numerical col.'Newspaper'

plt.figure(figsize=(5,5))
sns.histplot(data = dat1, x = "Newspaper",kde = True)
# Out:
# <Axes: xlabel='Newspaper', ylabel='Count'>

# %%
# Numerical col.'Newspaper'

plt.figure(figsize=(5,5))
sns.histplot(data = dat1, x = "Sales",kde = True)
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %% [markdown]
# ## Insights :
# *
# *
# *

# %% [markdown]
# ## BIVARIATE ANALYSIS

# %%
# Comparing each input ; input variable / column

# %%
sns.scatterplot(data = dat1 , x = 'TV', y = "Sales")
plt.title('Sales vs TV')
plt.show()

# Scatter plot is suitable to see the relationship  b/w the variables.

# %%
sns.scatterplot(data = dat1 , x = 'Newspaper', y = "Sales")
plt.title('Sales vs Newspaper')
plt.show()

# No relationship b/w Newspaper & Sales

# %%
sns.scatterplot(data = dat1 , x = 'Radio', y = "Sales")
plt.title('Sales vs Radio')
plt.show()

# No relationship b/w Newspaper & Sales

# %% [markdown]
# ## Insights :
#     * TV & sales cols. shows +ve relationship , but remaining tow cols. doesnt show any relations

# %%
# To check with linear regression assumptions ; 
'''
* Linearity
* no or less multi-collinearity
* It should have normal distribution
'''
# Out:
# '\n* Linearity\n* no or less multi-collinearity\n* It should have normal distribution\n'

# %%
sns.scatterplot(data = dat1, x = 'TV', y = 'Newspaper')
plt.title('TV vs Newspaper')
# Out:
# Text(0.5, 1.0, 'TV vs Newspaper')

# %%
# Radio vs newspaper
sns.scatterplot(data = dat1, x = 'Radio', y = 'Newspaper')
plt.title('Radio vs Newspaper')
# Out:
# Text(0.5, 1.0, 'Radio vs Newspaper')

# %% [markdown]
# ## Insights :
#      * In considering assumptions, it doesn't show any relation b/w input variable - not linear
#      * It has no collinearity
#      * Outliers present so its not an normal distribution

# %% [markdown]
# ## MULTIVARIATE ANALYSIS

# %%
sns.pairplot(data = dat1) # pair plot

# %% [markdown]
# ## DATA PREPROCESSING

# %%
# 1 Handling null values :

dat1.isnull().sum()

# Since no null values we're going with nwxt step
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
# 2 check for duplicates

# data.drop_duplicates() -> Incase duplicates are present.

dat1.duplicated().sum()
# Out:
# 0

# %%
# 3 Data encoding :

# %%
# 4 outliers handling

# %%
# 5 Scaling & balancing of data

# %% [markdown]
# ## FEATURE ENGINEERING /
#         * To check for unneccessary col.
#         * To remove relationship blw the cols.(by linear regression assumptions)

# %%
# we should have the copy of dataset before EDA process in the begining.

dataa = dat1.copy()
dataa
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
# after dropping of unneccassary cols.('unnanmed :0 ')
dataa
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
# Heatmap to see the corr b/w the variables.

sns.heatmap(dataa.corr(),annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ## Insights :
#     *
#     *
#     *

# %% [markdown]
# ## MODEL BUILDING / CREATION :

# %%
# spitting the data into x & y

# %%
# divide the data into input and target
X= dataa.drop('Sales', axis= 1)
y= dataa['Sales']

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
# Splitting into train & test data

# %%
# Divide the x and y into training and testing data 
# 100% data will be there.

# %%
'''
# For training maximum data will be sent for the model
# to train, (70%, 75%, 80%).

# For testing: minimum data is 20%, 25% or 30% will be 
# sent for testing, (new records) for the model.

# Test data: It is a total unknown record for the model
'''

# %%
# sklearn is a scientific library which has all the  functionalities of ML

from sklearn.model_selection import train_test_split  # this library is imported to splitting the datas to train & test
 
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size= 0.2, random_state= 4)  

# Here testsize  = 0.2 is 20% for testing , random state  = 4 is to saving the particular shuffle of data which is entering in testing side.

# %%
X.shape # 100% of data
# Out:
# (200, 4)

# %%
X_train.shape # 80% data for training
# Out:
# (160, 4)

# %%
X_test.shape  # 20% data for test
# Out:
# (40, 4)

# %% [markdown]
# ## ALGORITHM

# %%
# importing the algorithm
from sklearn.linear_model import LinearRegression # linear regressing model package

# initialize it
model= LinearRegression() # calling required func.  

# train the model
model.fit(X_train, y_train) # Fitting the data into the model
# Out:
# LinearRegression()

# %%
# We trained the model
# We need to test the model for the performance
# y pred -> target output

# %%
y_pred= model.predict(X_test) #

# %%
y_pred # predictions of sales(target variable)
# Out:
# array([17.26682961, 16.74943393, 21.97922965, 24.60245341, 12.10976233,
#        21.02174569, 10.15468999, 12.35073078, 11.70508844, 17.02865152,
#        22.77186055, 15.35498293,  8.48547227, 14.9174674 , 18.62371065,
#        18.79255083, 18.9160333 , 14.41815292,  9.66267174, 20.60438123,
#        14.91141015, 17.84685037, 23.05650902,  7.737869  , 21.55298757,
#        19.46197637, 13.93921155, 11.55027118, 18.37178325, 12.20117319,
#        11.34848167,  9.90606873, 13.57888332, 15.17716666, 18.06933248,
#         6.80836799, 14.14653363, 14.14569823, 14.16074282, 10.69550932])

# %%
# Now we've to compare actual y and predicted y and to find errors;
# errors  = diff b/w actual & predicted

# %%
y_test
# Out:
# 11     17.4
# 99     17.2
# 128    24.7
# 175    27.0
# 1      10.4
# 111    21.8
# 90     11.2
# 177    11.7
# 88     12.9
# 187    17.3
# 61     24.2
# 199    13.4
# 191     9.9
# 123    15.2
# 184    17.6
# 188    15.9
# 33     17.4
# 171    14.5
# 138     9.6
# 84     21.7
# 81     12.3
# 102    14.8
# 147    25.4
# 34      9.5
# 47     23.2
# 124    19.7
# 112    14.1
# 6      11.8
# 14     19.0
# 190    10.8
# 80     11.8
# 18     11.3
# 167    12.2
# 45     14.9
# 153    19.0
# 119     6.6
# 100    11.7
# 83     13.6
# 181    12.2
# 71     12.4
# Name: Sales, dtype: float64

# %%
# st.ine eqn is y = mx + c
# m-> slope
# c -> intercept

# %%
#  slopes values are given - (3 cols.) -> m
# m1 x1 + m2 x2 + m3 x3 + c = y
model.coef_
# Out:
# array([8.88677153e-05, 4.63526838e-02, 1.77708089e-01, 3.43416721e-04])

# %%
# intercept -> c 
model.intercept_
# Out:
# 3.047474181053623

# %% [markdown]
# ## Now error/Loss funcs :

# %%
# Error= Actual - Prediction
# MSE
# MAE
# RMSE
# takes 2 parameters y_test, y_pred

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
mse= mean_squared_error(y_test, y_pred)
mse
# Out:
# 2.2191889855255735

# %%
mae= mean_absolute_error(y_test, y_pred)
mae
# Out:
# 1.2122953042668587

# %%
import numpy as np
rmse = np.sqrt(mse)
rmse
# Out:
# 1.4896942590765305

# %% [markdown]
# ## R2 score :

# %%
r2_score(y_test, y_pred)  # ranges from 0->1 ; higher score indicates a better fit of model (ie) 90% score prediction
# Out:
# 0.9084934434517352
